# %% [markdown]
# # Hard Evaluation Questions for Multi-Agent Differentiation
#
# These questions are designed to stress-test multi-agent systems vs single-agent/baseline.
# They require **multi-step reasoning, intermediate computation, and cross-domain synthesis**.
#
# Each question has a **programmatic verifier** that checks the answer against ground truth
# computed from the same tools — no LLM-as-judge needed for pass/fail.
#
# **Import this notebook alongside `mp3_assignment.ipynb` — it reuses the same tools and DB.**
